# %% [markdown]
# <a href="https://colab.research.google.com/github/waqarmm/Object_detection_On_Road/blob/main/OD_MODULE_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install Roboflow**

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %% [markdown]
# **Generate Dataset after annotation**

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="kHMsuk3AWLwks3bfSlta")
project = rf.workspace("nust-w6xwh").project("moduleproject-od")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ModuleProject-OD-1 in yolov5pytorch:: 100%|██████████| 354/354 [00:00<00:00, 4422.75it/s]

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Import Yolo**

# %%
import ultralytics
from ultralytics import YOLO

from IPython.display import display, Image


# display.clear_output()


ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/107.7 GB disk)

# %%
import os
dataset_location = os.getcwd()


# set the path to the data.yaml file
data_yaml_path = "/content/datasets/ModuleProject-OD-1/data.yaml"

# %%
os.getcwd()
# Out:
# '/content'

# %%
# !chmod 777 '/content/ModuleProject-OD-1'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={data_yaml_path} epochs=50 imgsz=800 plots=True conf=0.25
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
import os
os.path.isfile('/content/ModuleProject-OD-1/data.yaml')
# Out:
# True

# %%
Image(filename=f'/content/runs/detect/train5/val_batch0_labels.jpg', width=800)

# %%
# !cp -R datasets/ drive/MyDrive/
